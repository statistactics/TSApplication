# %%
import pandas as pd 
from pathlib import Path
import os

# %%
train_df = pd.read_csv("Electric_Production.csv", parse_dates = ["DATE"])
train_df
# Out:
#           DATE  IPG2211A2N
# 0   1985-01-01     72.5052
# 1   1985-02-01     70.6720
# 2   1985-03-01     62.4502
# 3   1985-04-01     57.4714
# 4   1985-05-01     55.3151
# ..         ...         ...
# 392 2017-09-01     98.6154
# 393 2017-10-01     93.6137
# 394 2017-11-01     97.3359
# 395 2017-12-01    114.7212
# 396 2018-01-01    129.4048
#
# [397 rows x 2 columns]

# %%
train_df.set_index("DATE").plot(figsize = (16,10))

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Plot sales against holidays

# %% [markdown]
# # Get the cleaning out of the way ASAP and try out Bayesian models :)
