# %%
import pandas as pd 
from pathlib import Path
import os

# %% [markdown]
# # Electricity Production Data

# %%
train_df = pd.read_csv("Electric_Production.csv", parse_dates = ["DATE"])
train_df
# Out:
#            DATE  IPG2211A2N
# 0    1939-01-01      3.3336
# 1    1939-02-01      3.3591
# 2    1939-03-01      3.4354
# 3    1939-04-01      3.4609
# 4    1939-05-01      3.4609
# ...         ...         ...
# 1019 2023-12-01    109.7092
# 1020 2024-01-01    125.9059
# 1021 2024-02-01    107.1504
# 1022 2024-03-01    100.7498
# 1023 2024-04-01     92.0544
#
# [1024 rows x 2 columns]

# %%
train_df.rename(columns = {"IPG2211A2N": "Industrial_Production_Index"}, inplace=True)

# %%
train_df[train_df["DATE"].between("2017-01-01", "2017-12-31")]["Industrial_Production_Index"].mean()
# Out:
# 100.00000833333333

# %%
train_df.set_index("DATE").plot(figsize = (16,10))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# # Weather data and forecasts

# %% [markdown]
# # Sale of electronic goods

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Plot sales against holidays

# %% [markdown]
# # Get the cleaning out of the way ASAP and try out Bayesian models :)
